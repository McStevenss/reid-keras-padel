# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/padel/
# Out:
# data					     plots
# dataset					     plots0.png
# display_xy_coordinates_on_mouse_click.ipynb  plots.png
# downloads				     requirements.gdoc
# example_clips				     requirements.txt
# initial_padel.ipynb			     resnet50_fine_tune.ipynb
# model					     take_screenshots.ipynb
# output					     trim_padel.ipynb
# painted_frame0.jpg

# %%
# importing the module
import cv2
# from google.colab.patches import cv2_imshow 
# from google.colab.patches import cv2_imshow and display using cv2_imshow()


# function to display the coordinates of
# of the points clicked on the image
def click_event(event, x, y, flags, params):
 
    # checking for left mouse clicks
    if event == cv2.EVENT_LBUTTONDOWN:
 
        # displaying the coordinates
        # on the Shell
        print(x, ' ', y)
 
        # displaying the coordinates
        # on the image window
        font = cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(img, str(x) + ',' +
                    str(y), (x,y), font,
                    1, (255, 0, 0), 2)
        cv2.imshow("image", img)
 
    # checking for right mouse clicks    
    if event==cv2.EVENT_RBUTTONDOWN:
 
        # displaying the coordinates
        # on the Shell
        print(x, ' ', y)
 
        # displaying the coordinates
        # on the image window
        font = cv2.FONT_HERSHEY_SIMPLEX
        b = img[y, x, 0]
        g = img[y, x, 1]
        r = img[y, x, 2]
        cv2.putText(img, str(b) + ',' +
                    str(g) + ',' + str(r),
                    (x,y), font, 1,
                    (255, 255, 0), 2)
        cv2.imshow("image", img)
 
# driver function
if __name__=="__main__":
 
    # reading the image
    img = cv2.imread('C:\\Users\\jimhu\\Downloads\\painted_frame_volleyball0.jpg', 1)
    # C:\Users\jimhu\Desktop\painted_frame0.jpg
 
    # displaying the image
    cv2.imshow("image", img)
 
    # setting mouse handler for the image
    # and calling the click_event() function
    cv2.setMouseCallback('image', click_event)
 
    # wait for a key to be pressed to exit
    cv2.waitKey(0)
 
    # close the window
    cv2.destroyAllWindows()
# Out:
# 790   648
# 791   713
# 664   639
# 991   149
